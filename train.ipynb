# %%
# !git clone https://github.com/howardshu/cs188-cabinet-door-team11.git
# Out:
# Cloning into 'cs188-cabinet-door-team11'...
# remote: Enumerating objects: 96, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 96 (delta 30), reused 34 (delta 27), pack-reused 52 (from 2)
# Receiving objects: 100% (96/96), 78.46 KiB | 19.62 MiB/s, done.
# Resolving deltas: 100% (49/49), done.

# %%
# %cd cs188-cabinet-door-team11
# Out:
# /content/cs188-cabinet-door-team11

# %%
# !bash cabinet_door_project/colab_setup.sh
# Out:
# Updating apt packages...
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [85.2 kB]
# Get:5 https://cli.github.com/packages stable/main amd64 Packages [355 B]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,432 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATASET_PATH = "/content/drive/MyDrive/CS188-final-proj/OpenCabinet/20250819/lerobot"
CKPT_DIR = "/content/drive/MyDrive/CS188-final-proj/cabinet_policy_checkpoints"

# !python cabinet_door_project/06_train_policy.py \
  --policy vision_diffusion_chunk \
  --config cabinet_door_project/configs/diffusion_policy.yaml \
  --dataset_path "$DATASET_PATH" \
  --checkpoint_dir "$CKPT_DIR"
# Out:
# ...
#   OpenCabinet - Policy Training
# ...
#
# ...
#   Vision Diffusion Chunk Policy (Starter)
# ...
# Dataset: /content/drive/MyDrive/CS188-final-proj/OpenCabinet/20250819/lerobot
# Loaded 23623 sequence samples from 70 episodes (state_dim=16, action_dim=12)
# Train samples: 21261  Val samples: 2362
# Device: cuda
#
# ...
#   Training
# ...
# Epochs=120  Batch=16  LR=0.0001  n_obs=2  n_action=8  diff_steps=100
# Live logs every 50 steps
#     epoch    1 step    50 global_step      50 loss 1.002197
#     epoch    1 step   100 global_step     100 loss 1.001821
#     epoch    1 step   150 global_step     150 loss 0.999430
#     epoch    1 step   200 global_step     200 loss 0.999180
# We had to kill ffmpeg to stop it.
# object address  : 0x7a81048f2aa0
# object refcount : 3
# object type     : 0xa2a4e0
# object type name: KeyboardInterrupt
# object repr     : KeyboardInterrupt()
# lost sys.stderr
# ^C
